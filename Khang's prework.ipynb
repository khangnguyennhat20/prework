# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # HELLO WORLD
#
# Welcome to my prework assignment! My name is **Khang**
#
# Let's enjoy!
#
# ![image.png](attachment:image.png)

# %%
df = pd.read_excel("D:\BodyFat.xls")
df.head(10)
# Out:
#    IDNO  BODYFAT  DENSITY  AGE  WEIGHT  HEIGHT  ADIPOSITY  NECK  CHEST  \
# 0     1     12.6   1.0708   23  154.25   67.75       23.7  36.2   93.1
# 1     2      6.9   1.0853   22  173.25   72.25       23.4  38.5   93.6
# 2     3     24.6   1.0414   22  154.00   66.25       24.7  34.0   95.8
# 3     4     10.9   1.0751   26  184.75   72.25       24.9  37.4  101.8
# 4     5     27.8   1.0340   24  184.25   71.25       25.6  34.4   97.3
# 5     6     20.6   1.0502   24  210.25   74.75       26.5  39.0  104.5
# 6     7     19.0   1.0549   26  181.00   69.75       26.2  36.4  105.1
# 7     8     12.8   1.0704   25  176.00   72.50       23.6  37.8   99.6
# 8     9      5.1   1.0900   25  191.00   74.00       24.6  38.1  100.9
# 9    10     12.0   1.0722   23  198.25   73.50       25.8  42.1   99.6
#
#    ABDOMEN    HIP  THIGH  KNEE  ANKLE  BICEPS  FOREARM  WRIST
# 0     85.2   94.5   59.0  37.3   21.9    32.0     27.4   17.1
# 1     83.0   98.7   58.7  37.3   23.4    30.5     28.9   18.2
# ...

# %%
df["ADIPOSITY"].corr(df["NECK"])
# Out:
# 0.7778569071784194

# %%
df["ADIPOSITY"].corr(df["CHEST"])
# Out:
# 0.9117986490778511

# %%
df["ADIPOSITY"].corr(df["ADIPOSITY"])
# Out:
# 1.0

# %%
df.corr()["ADIPOSITY"]
# Out:
# IDNO         0.047717
# BODYFAT      0.727994
# DENSITY     -0.714732
# AGE          0.118851
# WEIGHT       0.887352
# HEIGHT      -0.024891
# ADIPOSITY    1.000000
# NECK         0.777857
# CHEST        0.911799
# ABDOMEN      0.923880
# HIP          0.883269
# THIGH        0.812706
# KNEE         0.713660
# ANKLE        0.500317
# BICEPS       0.746384
# FOREARM      0.558594
# WRIST        0.625907
# Name: ADIPOSITY, dtype: float64

# %%
plt.matshow(df.corr())

# %%
def plot_corr_with_labels(df):
    corr = df.corr()
    fig, ax = plt.subplots(figsize=(20,20))
    ax.matshow(corr)
    plt.xticks(range(len(corr.columns)), corr.columns)
    plt.yticks(range(len(corr.columns)), corr.columns)

# %%
plot_corr_with_labels(df)

# %%
under_45 = df[df["AGE"] < 45]
over_45 = df[df["AGE"] >= 45]

print(under_45.size)
print(over_45.size)
# Out:
# 2312
# 1972

# %%
u45 = under_45.corr()["ADIPOSITY"]
o45 = over_45.corr()["ADIPOSITY"]

for i in range(df.columns.values.size):
    print (u45[i] - o45[i])
# Out:
# 0.05891215582800935
# -0.04490096372751273
# 0.02861417819300538
# 0.024507558141896868
# 0.0049510416404691115
# 0.03514388196089998
# 0.0
# -0.030663409124133456
# 0.004175860726502445
# -0.020820580840045233
# -0.010269505864226813
# 0.03210502074934207
# 0.10830842534469676
# -0.06194043011693734
# 0.08871955387814023
# -0.014162800579309187
# 0.036528410574490966

# %%
list(df.columns.values)
# Out:
# ['IDNO',
#  'BODYFAT',
#  'DENSITY',
#  'AGE',
#  'WEIGHT',
#  'HEIGHT',
#  'ADIPOSITY',
#  'NECK',
#  'CHEST',
#  'ABDOMEN',
#  'HIP',
#  'THIGH',
#  'KNEE',
#  'ANKLE',
#  'BICEPS',
#  'FOREARM',
#  'WRIST']

# %%
(o45-u45).to_frame('delta').abs().sort_values('delta',ascending=False)
# Out:
#               delta
# KNEE       0.108308
# BICEPS     0.088720
# ANKLE      0.061940
# IDNO       0.058912
# BODYFAT    0.044901
# WRIST      0.036528
# HEIGHT     0.035144
# THIGH      0.032105
# NECK       0.030663
# DENSITY    0.028614
# AGE        0.024508
# ABDOMEN    0.020821
# FOREARM    0.014163
# HIP        0.010270
# WEIGHT     0.004951
# CHEST      0.004176
# ADIPOSITY  0.000000

# %% [markdown]
# #The characteristic as it relates to predicting someone's adiposity that changes most between people under 45 and people 45 and over is:
# **KNEE**
# #This characteristic changes by 0.108308
#
# ![image.png](attachment:image.png)
